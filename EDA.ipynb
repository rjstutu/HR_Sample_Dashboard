# %%
import os
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cwd = os.getcwd()
data_file = f"{cwd}/input_data/raw_hr_data.csv"
df_hr = pd.read_csv(data_file)
df_hr.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ## Get a glimpse of data, understand the data size and format.

# %%
df_hr.info()
df_hr.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Department', data=df_hr)
plt.title('Department Distribution')
plt.xlabel('Department')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Gender', data=df_hr)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
## explore satisfaction level and years at company
# exp_satis_corr = df_hr[['JobSatisfaction ', 'YearsAtCompany']].corr()

print(exp_satis_corr)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\renjo\Projects\HR_Dashboard\human-resource-data-analysis-streamlit\EDA.ipynb Cell 7 in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/renjo/Projects/HR_Dashboard/human-resource-data-analysis-streamlit/EDA.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> ## explore satisfaction level and years at company
# ----> <a href='vscode-notebook-cell:/c%3A/Users/renjo/Projects/HR_Dashboard/human-resource-data-analysis-streamlit/EDA.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> exp_satis_corr = df_hr[['JobSatisfaction ', 'YearsAtCompany']].corr()
#       <a href='vscode-notebook-cell:/c%3A/Users/renjo/Projects/HR_Dashboard/human-resource-data-analysis-streamlit/EDA.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> print(exp_satis_corr)
#
# ...

# %%
df_hr.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# C:\Users\renjo\AppData\Local\Temp\ipykernel_2764\3904976643.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_hr.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# C:\Users\renjo\AppData\Local\Temp\ipykernel_2764\3904976643.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df_hr.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# c:\Users\renjo\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\formats\style.py:3926: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# c:\Users\renjo\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\formats\style.py:3927: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# ...
